# %%
import numpy as np
from scipy.optimize import curve_fit
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches
import matplotlib.cm as cm
from matplotlib.ticker import AutoMinorLocator
from sklearn.linear_model import LinearRegression
from matplotlib.legend_handler import HandlerTuple
import matplotlib.ticker as ticker
import IPython
import imgkit
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %% [markdown]
# # CTAB (C16) + NaSal -> WLMs

# %%
CTAB0025Nasal00125_0cnf = '/Users/ningravi/Desktop/Python/Raw Data WLM and CNF/8_02_23/20230801_0CNF0.025CTAB0.0125NaSal_(RH made62923).xls'
CTAB0025Nasal00125_001cnf = '/Users/ningravi/Desktop/Python/Raw Data WLM and CNF/8_02_23/20230801_0.01CNF0.025CTAB0.0125NaSal_(RH made62923) (2).xls'
CTAB0025Nasal00125_005cnf = '/Users/ningravi/Desktop/Python/Raw Data WLM and CNF/8_02_23/20230801_0.05CNF0.025CTAB0.0125NaSal_(RH made62923).xls'
CTAB0025Nasal00125_01cnf = '/Users/ningravi/Desktop/Python/Raw Data WLM and CNF/8_02_23/20230801_0.1CNF0.025CTAB0.0125NaSal_(RH made62923).xls'

# %%
#Amplitude Sweeps
start_row = 3
end_row = 33

CTAB0025Nasal00125_0cnf_strain_in1 = pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Amplitude - 1', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_0cnf_g1_in1= pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Amplitude - 1', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_0cnf_g2_in1 = pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Amplitude - 1', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_0cnf_strain_de1 = pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Amplitude - 2', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_0cnf_g1_de1= pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Amplitude - 2', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_0cnf_g2_de1 = pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Amplitude - 2', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_0cnf_strain_in2 = pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Amplitude - 3', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_0cnf_g1_in2= pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Amplitude - 3', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_0cnf_g2_in2 = pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Amplitude - 3', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

# %%
#Amplitude Sweeps
start_row = 3
end_row = 33

CTAB0025Nasal00125_001cnf_strain_in1 = pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Amplitude - 1', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_001cnf_g1_in1= pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Amplitude - 1', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_001cnf_g2_in1 = pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Amplitude - 1', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_001cnf_strain_de1 = pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Amplitude - 2', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_001cnf_g1_de1= pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Amplitude - 2', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_001cnf_g2_de1 = pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Amplitude - 2', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_001cnf_strain_in2 = pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Amplitude - 3', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_001cnf_g1_in2= pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Amplitude - 3', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_001cnf_g2_in2 = pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Amplitude - 3', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

# %%
#Amplitude Sweeps
start_row = 3
end_row = 33

CTAB0025Nasal00125_005cnf_strain_in1 = pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Amplitude - 1', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_005cnf_g1_in1= pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Amplitude - 1', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_005cnf_g2_in1 = pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Amplitude - 1', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_005cnf_strain_de1 = pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Amplitude - 2', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_005cnf_g1_de1= pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Amplitude - 2', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_005cnf_g2_de1 = pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Amplitude - 2', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_005cnf_strain_in2 = pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Amplitude - 3', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_005cnf_g1_in2= pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Amplitude - 3', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_005cnf_g2_in2 = pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Amplitude - 3', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

# %%
#Amplitude Sweeps
start_row = 3
end_row = 33

CTAB0025Nasal00125_01cnf_strain_in1 = pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Amplitude - 1', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_01cnf_g1_in1= pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Amplitude - 1', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_01cnf_g2_in1 = pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Amplitude - 1', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_01cnf_strain_de1 = pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Amplitude - 2', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_01cnf_g1_de1= pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Amplitude - 2', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_01cnf_g2_de1 = pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Amplitude - 2', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_01cnf_strain_in2 = pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Amplitude - 3', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_01cnf_g1_in2= pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Amplitude - 3', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_01cnf_g2_in2 = pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Amplitude - 3', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

# %%
CTAB0025Nasal00125_0cnf_strain = [CTAB0025Nasal00125_0cnf_strain_in1, CTAB0025Nasal00125_0cnf_strain_de1, CTAB0025Nasal00125_0cnf_strain_in2]
CTAB0025Nasal00125_0cnf_g1 = [CTAB0025Nasal00125_0cnf_g1_in1, CTAB0025Nasal00125_0cnf_g1_de1, CTAB0025Nasal00125_0cnf_g1_in2]
CTAB0025Nasal00125_0cnf_g2 = [CTAB0025Nasal00125_0cnf_g2_in1, CTAB0025Nasal00125_0cnf_g2_de1, CTAB0025Nasal00125_0cnf_g2_in2]
CTAB0025Nasal00125_0cnf_label_g1 = ['.', '.', '.']
CTAB0025Nasal00125_0cnf_label_g2 = ['1st Increasing γ', '1st Decreasing γ', '2nd Increasing γ']
markers = ['^','v', 'o']
alphas = [0.2, 0.4, 0.8]
c='k'
# Plot the data
fig, ax = plt.subplots(figsize=(6, 6))

for idx, (x, y1, y2, m, a, label1, label2) in enumerate(zip(CTAB0025Nasal00125_0cnf_strain, CTAB0025Nasal00125_0cnf_g1, CTAB0025Nasal00125_0cnf_g2, markers, alphas, CTAB0025Nasal00125_0cnf_label_g1, CTAB0025Nasal00125_0cnf_label_g2)):
    scatter1 = plt.scatter(x, y1, s =200, alpha = a,
                marker= m, facecolors=c, edgecolors=c, linewidths=2, label=label1)
    scatter2 = plt.scatter(x, y2, s =200, alpha = a,
                marker= m, edgecolors=c, linewidths=2, label=label2)
    scatter2.set_facecolor('none') 
  

plt.style.use('seaborn-notebook')
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Oscillatory strain, γ (%)', fontsize=20)
plt.ylabel("Storage modulus, G' (Pa) \n Loss modulus, G'' (Pa)", fontsize=20)

legend_handles = [(scatter1, scatter2) for scatter1, scatter2 in zip(scatter1.get_paths(), scatter2.get_paths())]
legend_labels = CTAB0025Nasal00125_0cnf_strain

handler_map = {}
for handle, label in zip(legend_handles, legend_labels):
    handler_map[handle] = HandlerTuple(ndivide=None, pad=0.3)

handles, labels = plt.gca().get_legend_handles_labels()
handles = handles[1::2] + handles[::2]  # Combine G1 and G2 handles
labels =  labels[1::2] + labels[::2]   # Combine G1 and G2 labels

label_colors = ['white' if i < 3 else 'black' for i in range(len(labels))]
legend = plt.legend(handles[::-1], labels[::-1], frameon=False, fontsize=14, 
           handler_map=handler_map, labelcolor=label_colors, ncol =2,
          handlelength=-5, handletextpad=4, loc = (0.63,0.72))

plt.subplots_adjust(left=0.01, right=0.9, top=0.9, bottom=0.1)  # Adjust the values as needed
 
plt.text(4.1, 7, "G' G''", fontsize=14, color='black')

plt.tick_params(axis='y', length=5, width=1, color='black', direction='out')
plt.tick_params(axis='x', length=5, width=1, color='black', direction='out')
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlim(0.1, 100)
plt.ylim(0.1, 10)
#plt.savefig("Amplitude Sweeps of WLM(CTAB&NaSal) at 25C.png", dpi=1500, bbox_inches='tight')
plt.show()

# %%
#frequency Sweeps
start_row = 3
end_row = 33

CTAB0025Nasal00125_0cnf_fre_25C = pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Frequency - 4', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_0cnf_g1_fre_25C= pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Frequency - 4', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_0cnf_g2_fre_25C = pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Frequency - 4', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_0cnf_fre_30C = pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Frequency - 5', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_0cnf_g1_fre_30C= pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Frequency - 5', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_0cnf_g2_fre_30C = pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Frequency - 5', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_0cnf_fre_35C = pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Frequency - 6', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_0cnf_g1_fre_35C= pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Frequency - 6', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_0cnf_g2_fre_35C = pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Frequency - 6', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_0cnf_fre_40C = pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Frequency - 7', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_0cnf_g1_fre_40C= pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Frequency - 7', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_0cnf_g2_fre_40C = pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Frequency - 7', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_0cnf_fre_45C = pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Frequency - 8', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_0cnf_g1_fre_45C= pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Frequency - 8', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_0cnf_g2_fre_45C = pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Frequency - 8', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_0cnf_fre_50C = pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Frequency - 9', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_0cnf_g1_fre_50C= pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Frequency - 9', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_0cnf_g2_fre_50C = pd.read_excel(CTAB0025Nasal00125_0cnf, sheet_name='Frequency - 9', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

# %%
#frequency Sweeps
start_row = 3
end_row = 33

CTAB0025Nasal00125_001cnf_fre_25C = pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Frequency - 4', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_001cnf_g1_fre_25C= pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Frequency - 4', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_001cnf_g2_fre_25C = pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Frequency - 4', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_001cnf_fre_30C = pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Frequency - 5', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_001cnf_g1_fre_30C= pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Frequency - 5', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_001cnf_g2_fre_30C = pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Frequency - 5', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_001cnf_fre_35C = pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Frequency - 6', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_001cnf_g1_fre_35C= pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Frequency - 6', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_001cnf_g2_fre_35C = pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Frequency - 6', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_001cnf_fre_40C = pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Frequency - 7', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_001cnf_g1_fre_40C= pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Frequency - 7', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_001cnf_g2_fre_40C = pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Frequency - 7', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_001cnf_fre_45C = pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Frequency - 8', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_001cnf_g1_fre_45C= pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Frequency - 8', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_001cnf_g2_fre_45C = pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Frequency - 8', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_001cnf_fre_50C = pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Frequency - 9', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_001cnf_g1_fre_50C= pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Frequency - 9', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_001cnf_g2_fre_50C = pd.read_excel(CTAB0025Nasal00125_001cnf, sheet_name='Frequency - 9', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

# %%
#frequency Sweeps
start_row = 3
end_row = 33

CTAB0025Nasal00125_005cnf_fre_25C = pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Frequency - 4', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_005cnf_g1_fre_25C= pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Frequency - 4', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_005cnf_g2_fre_25C = pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Frequency - 4', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_005cnf_fre_30C = pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Frequency - 5', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_005cnf_g1_fre_30C= pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Frequency - 5', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_005cnf_g2_fre_30C = pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Frequency - 5', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_005cnf_fre_35C = pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Frequency - 6', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_005cnf_g1_fre_35C= pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Frequency - 6', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_005cnf_g2_fre_35C = pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Frequency - 6', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_005cnf_fre_40C = pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Frequency - 7', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_005cnf_g1_fre_40C= pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Frequency - 7', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_005cnf_g2_fre_40C = pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Frequency - 7', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_005cnf_fre_45C = pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Frequency - 8', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_005cnf_g1_fre_45C= pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Frequency - 8', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_005cnf_g2_fre_45C = pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Frequency - 8', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_005cnf_fre_50C = pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Frequency - 9', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_005cnf_g1_fre_50C= pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Frequency - 9', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_005cnf_g2_fre_50C = pd.read_excel(CTAB0025Nasal00125_005cnf, sheet_name='Frequency - 9', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

# %%
#frequency Sweeps
start_row = 3
end_row = 33

CTAB0025Nasal00125_01cnf_fre_25C = pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Frequency - 4', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_01cnf_g1_fre_25C= pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Frequency - 4', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_01cnf_g2_fre_25C = pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Frequency - 4', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_01cnf_fre_30C = pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Frequency - 5', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_01cnf_g1_fre_30C= pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Frequency - 5', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_01cnf_g2_fre_30C = pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Frequency - 5', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_01cnf_fre_35C = pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Frequency - 6', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_01cnf_g1_fre_35C= pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Frequency - 6', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_01cnf_g2_fre_35C = pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Frequency - 6', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_01cnf_fre_40C = pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Frequency - 7', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_01cnf_g1_fre_40C= pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Frequency - 7', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_01cnf_g2_fre_40C = pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Frequency - 7', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_01cnf_fre_45C = pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Frequency - 8', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_01cnf_g1_fre_45C= pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Frequency - 8', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_01cnf_g2_fre_45C = pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Frequency - 8', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

CTAB0025Nasal00125_01cnf_fre_50C = pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Frequency - 9', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_01cnf_g1_fre_50C= pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Frequency - 9', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
CTAB0025Nasal00125_01cnf_g2_fre_50C = pd.read_excel(CTAB0025Nasal00125_01cnf, sheet_name='Frequency - 9', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

# %%
CTAB0025Nasal00125_25C_fre = [CTAB0025Nasal00125_0cnf_fre_25C, CTAB0025Nasal00125_001cnf_fre_25C, CTAB0025Nasal00125_005cnf_fre_25C, CTAB0025Nasal00125_01cnf_fre_25C] 
CTAB0025Nasal00125_25C_g1_fre = [CTAB0025Nasal00125_0cnf_g1_fre_25C, CTAB0025Nasal00125_001cnf_g1_fre_25C, CTAB0025Nasal00125_005cnf_g1_fre_25C, CTAB0025Nasal00125_01cnf_g1_fre_25C]
CTAB0025Nasal00125_25C_g2_fre = [CTAB0025Nasal00125_0cnf_g2_fre_25C, CTAB0025Nasal00125_001cnf_g2_fre_25C, CTAB0025Nasal00125_005cnf_g2_fre_25C, CTAB0025Nasal00125_01cnf_g2_fre_25C]

CTAB0025Nasal00125_30C_fre = [CTAB0025Nasal00125_0cnf_fre_30C, CTAB0025Nasal00125_001cnf_fre_30C, CTAB0025Nasal00125_005cnf_fre_30C, CTAB0025Nasal00125_01cnf_fre_30C] 
CTAB0025Nasal00125_30C_g1_fre = [CTAB0025Nasal00125_0cnf_g1_fre_30C, CTAB0025Nasal00125_001cnf_g1_fre_30C, CTAB0025Nasal00125_005cnf_g1_fre_30C, CTAB0025Nasal00125_01cnf_g1_fre_30C]
CTAB0025Nasal00125_30C_g2_fre = [CTAB0025Nasal00125_0cnf_g2_fre_30C, CTAB0025Nasal00125_001cnf_g2_fre_30C, CTAB0025Nasal00125_005cnf_g2_fre_30C, CTAB0025Nasal00125_01cnf_g2_fre_30C]

CTAB0025Nasal00125_35C_fre = [CTAB0025Nasal00125_0cnf_fre_35C, CTAB0025Nasal00125_001cnf_fre_35C, CTAB0025Nasal00125_005cnf_fre_35C, CTAB0025Nasal00125_01cnf_fre_35C] 
CTAB0025Nasal00125_35C_g1_fre = [CTAB0025Nasal00125_0cnf_g1_fre_35C, CTAB0025Nasal00125_001cnf_g1_fre_35C, CTAB0025Nasal00125_005cnf_g1_fre_35C, CTAB0025Nasal00125_01cnf_g1_fre_35C]
CTAB0025Nasal00125_35C_g2_fre = [CTAB0025Nasal00125_0cnf_g2_fre_35C, CTAB0025Nasal00125_001cnf_g2_fre_35C, CTAB0025Nasal00125_005cnf_g2_fre_35C, CTAB0025Nasal00125_01cnf_g2_fre_35C]

CTAB0025Nasal00125_40C_fre = [CTAB0025Nasal00125_0cnf_fre_40C, CTAB0025Nasal00125_001cnf_fre_40C, CTAB0025Nasal00125_005cnf_fre_40C, CTAB0025Nasal00125_01cnf_fre_40C] 
CTAB0025Nasal00125_40C_g1_fre = [CTAB0025Nasal00125_0cnf_g1_fre_40C, CTAB0025Nasal00125_001cnf_g1_fre_40C, CTAB0025Nasal00125_005cnf_g1_fre_40C, CTAB0025Nasal00125_01cnf_g1_fre_40C]
CTAB0025Nasal00125_40C_g2_fre = [CTAB0025Nasal00125_0cnf_g2_fre_40C, CTAB0025Nasal00125_001cnf_g2_fre_40C, CTAB0025Nasal00125_005cnf_g2_fre_40C, CTAB0025Nasal00125_01cnf_g2_fre_40C]

CTAB0025Nasal00125_45C_fre = [CTAB0025Nasal00125_0cnf_fre_45C, CTAB0025Nasal00125_001cnf_fre_45C, CTAB0025Nasal00125_005cnf_fre_45C, CTAB0025Nasal00125_01cnf_fre_45C] 
CTAB0025Nasal00125_45C_g1_fre = [CTAB0025Nasal00125_0cnf_g1_fre_45C, CTAB0025Nasal00125_001cnf_g1_fre_45C, CTAB0025Nasal00125_005cnf_g1_fre_45C, CTAB0025Nasal00125_01cnf_g1_fre_45C]
CTAB0025Nasal00125_45C_g2_fre = [CTAB0025Nasal00125_0cnf_g2_fre_45C, CTAB0025Nasal00125_001cnf_g2_fre_45C, CTAB0025Nasal00125_005cnf_g2_fre_45C, CTAB0025Nasal00125_01cnf_g2_fre_45C]

CTAB0025Nasal00125_label_g1 = ['.', '.', '.', '.']
CTAB0025Nasal00125_label_g2 = ['0', '0.01', '0.05', '0.1']

# %%
cmap = plt.get_cmap('magma')

# Plot the data
fig, ax = plt.subplots(figsize=(6, 6))

for idx, (x, y1, y2, label1, label2) in enumerate(zip(CTAB0025Nasal00125_25C_fre, CTAB0025Nasal00125_25C_g1_fre, CTAB0025Nasal00125_25C_g2_fre, CTAB0025Nasal00125_label_g1,CTAB0025Nasal00125_label_g2)):
    c = cmap(float(idx) / len(CTAB0025Nasal00125_25C_fre))
    scatter1 = plt.scatter(x, y1, c=np.atleast_2d(c), s =200, alpha = 1,
                marker='o', facecolors=c, edgecolors=c, linewidths=3, label=label1)
    scatter2 = plt.scatter(x, y2, c=np.atleast_2d(c), s =200, alpha = 1,
                marker='o', edgecolors=c, linewidths=3, label=label2)
    scatter2.set_facecolor('none') 
    #plot1 = plt.plot(x, y1, '-', c=c,  linewidth=2, alpha=0.7)
    #plot2 = plt.plot(x, y2, '-', c=c,  linewidth=2, alpha=0.7)   

plt.style.use('seaborn-notebook')
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Angular frequency, \u03C9 (rad/s)', fontsize=20)
plt.ylabel("Storage modulus, G' (Pa) \n Loss modulus, G'' (Pa)", fontsize=20)

legend_handles = [(scatter1, scatter2) for scatter1, scatter2 in zip(scatter1.get_paths(), scatter2.get_paths())]
legend_labels = CTAB0025Nasal00125_label_g2 

handler_map = {}
for handle, label in zip(legend_handles, legend_labels):
    handler_map[handle] = HandlerTuple(ndivide=None, pad=0.3)

handles, labels = plt.gca().get_legend_handles_labels()
handles = handles[1::2] + handles[::2]  # Combine G1 and G2 handles
labels =  labels[1::2] + labels[::2]   # Combine G1 and G2 labels

label_colors = ['white' if i < 4 else 'black' for i in range(len(labels))]
legend = plt.legend(handles[::-1], labels[::-1], frameon=False, fontsize=14, 
           handler_map=handler_map, labelcolor=label_colors, ncol =2,
          handlelength=-4, handletextpad=4, loc = 'lower right')

plt.subplots_adjust(left=0.01, right=0.9, top=0.9, bottom=0.1)  # Adjust the values as needed
 
plt.text(8.5, 0.1, "G'    G''     [CNF]", fontsize=14, color='black')
plt.text(7.5, 0.07, "(Pa)  (Pa)   (wt.%)", fontsize=14, color='black')

plt.tick_params(axis='y', length=5, width=1, color='black', direction='out')
plt.tick_params(axis='x', length=5, width=1, color='black', direction='out')
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlim(0.1, 50)
plt.ylim(0.01, 10)
#plt.savefig("Frequency Sweeps WLM(CTAB&NaSal) Varying CNF Concentrations at 25C.png", dpi=1500, bbox_inches='tight')
plt.show()

# %%
cmap = plt.get_cmap('magma')

# Plot the data
fig, ax = plt.subplots(figsize=(6, 6))

for idx, (x, y1, y2, label1, label2) in enumerate(zip(CTAB0025Nasal00125_30C_fre, CTAB0025Nasal00125_30C_g1_fre, CTAB0025Nasal00125_30C_g2_fre, CTAB0025Nasal00125_label_g1,CTAB0025Nasal00125_label_g2)):
    c = cmap(float(idx) / len(CTAB0025Nasal00125_30C_fre))
    scatter1 = plt.scatter(x, y1, c=np.atleast_2d(c), s =200, alpha = 1,
                marker='o', facecolors=c, edgecolors=c, linewidths=3, label=label1)
    scatter2 = plt.scatter(x, y2, c=np.atleast_2d(c), s =200, alpha = 1,
                marker='o', edgecolors=c, linewidths=3, label=label2)
    scatter2.set_facecolor('none')
    #plot1 = plt.plot(x, y1, '-', c=c,  linewidth=2, alpha=0.5)
    #plot2 = plt.plot(x, y2, '-', c=c,  linewidth=2, alpha=0.5)

plt.style.use('seaborn-notebook')
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Angular frequency, \u03C9 (rad/s)', fontsize=20)
plt.ylabel("Storage modulus, G' (Pa) \n Loss modulus, G'' (Pa)", fontsize=20)

legend_handles = [(scatter1, scatter2) for scatter1, scatter2 in zip(scatter1.get_paths(), scatter2.get_paths())]
legend_labels = CTAB0025Nasal00125_label_g2 

handler_map = {}
for handle, label in zip(legend_handles, legend_labels):
    handler_map[handle] = HandlerTuple(ndivide=None, pad=0.3)

handles, labels = plt.gca().get_legend_handles_labels()
handles = handles[1::2] + handles[::2]  # Combine G1 and G2 handles
labels =  labels[1::2] + labels[::2]   # Combine G1 and G2 labels

label_colors = ['white' if i < 4 else 'black' for i in range(len(labels))]
legend = plt.legend(handles[::-1], labels[::-1], frameon=False, fontsize=14, 
           handler_map=handler_map, labelcolor=label_colors, ncol =2,
          handlelength=-4, handletextpad=4, loc = 'lower right')

plt.subplots_adjust(left=0.01, right=0.9, top=0.9, bottom=0.1)  # Adjust the values as needed
 
plt.text(8.5, 0.1, "G'    G''     [CNF]", fontsize=14, color='black')
plt.text(7.5, 0.07, "(Pa)  (Pa)   (wt.%)", fontsize=14, color='black')

plt.tick_params(axis='y', length=5, width=1, color='black', direction='out')
plt.tick_params(axis='x', length=5, width=1, color='black', direction='out')
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlim(0.1, 50)
plt.ylim(0.01, 10)
#plt.savefig("Frequency Sweeps WLM(CTAB&NaSal) Varying CNF Concentrations at 30C.png", dpi=1500, bbox_inches='tight')
plt.show()

# %%
cmap = plt.get_cmap('magma')

# Plot the data
fig, ax = plt.subplots(figsize=(6, 6))


for idx, (x, y3, y4, label1, label2) in enumerate(zip(CTAB0025Nasal00125_35C_fre, CTAB0025Nasal00125_35C_g1_fre, CTAB0025Nasal00125_35C_g2_fre, CTAB0025Nasal00125_label_g1,CTAB0025Nasal00125_label_g2)):
    c = cmap(float(idx) / len(CTAB0025Nasal00125_35C_fre))
    scatter1 = plt.scatter(x, y3, c=np.atleast_2d(c), s =200, alpha = 1,
                marker='o', facecolors=c, edgecolors=c, linewidths=2, label=label1)
    scatter2 = plt.scatter(x, y4, c=np.atleast_2d(c), s =200, alpha = 1,
                marker='o', edgecolors=c, linewidths=2, label=label2)
    scatter2.set_facecolor('none') 
    #plot1 = plt.plot(x, y3, '-', c=c,  linewidth=2, alpha=0.7)
    #plot2 = plt.plot(x, y4, '-', c=c,  linewidth=2, alpha=0.7)
    

plt.style.use('seaborn-notebook')
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Angular frequency, \u03C9 (rad/s)', fontsize=20)
plt.ylabel("Storage modulus, G' (Pa) \n Loss modulus, G'' (Pa)", fontsize=20)

legend_handles = [(scatter1, scatter2) for scatter1, scatter2 in zip(scatter1.get_paths(), scatter2.get_paths())]
legend_labels = CTAB0025Nasal00125_label_g2 

handler_map = {}
for handle, label in zip(legend_handles, legend_labels):
    handler_map[handle] = HandlerTuple(ndivide=None, pad=0.3)

handles, labels = plt.gca().get_legend_handles_labels()
handles = handles[1::2] + handles[::2]  # Combine G1 and G2 handles
labels =  labels[1::2] + labels[::2]   # Combine G1 and G2 labels

label_colors = ['white' if i < 4 else 'black' for i in range(len(labels))]
legend = plt.legend(handles[::-1], labels[::-1], frameon=False, fontsize=14, 
           handler_map=handler_map, labelcolor=label_colors, ncol =2,
          handlelength=-4, handletextpad=4, loc = 'lower right')

plt.subplots_adjust(left=0.01, right=0.9, top=0.9, bottom=0.1)  # Adjust the values as needed
 
plt.text(8.5, 0.1, "G'    G''  [CNF]", fontsize=14, color='black')
plt.text(7.5, 0.07, "(Pa)  (Pa) (wt.%)", fontsize=14, color='black')

plt.tick_params(axis='y', length=5, width=1, color='black', direction='out')
plt.tick_params(axis='x', length=5, width=1, color='black', direction='out')
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlim(0.1, 50)
plt.ylim(0.01, 10)
#plt.savefig("Frequency Sweeps WLM(CTAB&NaSal) Varying CNF Concentrations at 35C.png", dpi=1500, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Ethoquad (C23) NaSal -> WLM

# %%
ETQ07NaSal015_0cnf = '/Users/ningravi/Desktop/Python/Raw Data WLM and CNF/8_02_23/20230802_0CNF0.7ETQ0.15NaSal_(NW made80223).xls'
ETQ07NaSal015_001cnf = '/Users/ningravi/Desktop/Python/Raw Data WLM and CNF/8_02_23/20230802_0.01CNF0.7ETQ0.15NaSal_(NW made80223).xls'
ETQ07NaSal015_005cnf = '/Users/ningravi/Desktop/Python/Raw Data WLM and CNF/8_02_23/20230803_0.05CNF0.7ETQ0.15NaSal_(NW made80223).xls'
ETQ07NaSal015_01cnf = '/Users/ningravi/Desktop/Python/Raw Data WLM and CNF/8_02_23/20230803_0.1CNF0.7ETQ0.15NaSal_(NW made80223).xls'

# %%
#Amplitude Sweeps
start_row = 3
end_row = 33

ETQ07NaSal015_0cnf_strain_in1 = pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Amplitude - 1', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_0cnf_g1_in1= pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Amplitude - 1', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_0cnf_g2_in1 = pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Amplitude - 1', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

ETQ07NaSal015_0cnf_strain_de1 = pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Amplitude - 2', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_0cnf_g1_de1= pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Amplitude - 2', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_0cnf_g2_de1 = pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Amplitude - 2', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

ETQ07NaSal015_0cnf_strain_in2 = pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Amplitude - 3', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_0cnf_g1_in2= pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Amplitude - 3', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_0cnf_g2_in2 = pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Amplitude - 3', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

# %%
#Amplitude Sweeps
start_row = 3
end_row = 33

ETQ07NaSal015_001cnf_strain_in1 = pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Amplitude - 1', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_001cnf_g1_in1= pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Amplitude - 1', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_001cnf_g2_in1 = pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Amplitude - 1', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

ETQ07NaSal015_001cnf_strain_de1 = pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Amplitude - 2', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_001cnf_g1_de1= pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Amplitude - 2', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_001cnf_g2_de1 = pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Amplitude - 2', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

ETQ07NaSal015_001cnf_strain_in2 = pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Amplitude - 3', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_001cnf_g1_in2= pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Amplitude - 3', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_001cnf_g2_in2 = pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Amplitude - 3', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

# %%
#Amplitude Sweeps
start_row = 3
end_row = 33

ETQ07NaSal015_005cnf_strain_in1 = pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Amplitude - 1', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_005cnf_g1_in1= pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Amplitude - 1', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_005cnf_g2_in1 = pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Amplitude - 1', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

ETQ07NaSal015_005cnf_strain_de1 = pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Amplitude - 2', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_005cnf_g1_de1= pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Amplitude - 2', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_005cnf_g2_de1 = pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Amplitude - 2', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

ETQ07NaSal015_005cnf_strain_in2 = pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Amplitude - 3', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_005cnf_g1_in2= pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Amplitude - 3', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_005cnf_g2_in2 = pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Amplitude - 3', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

# %%
#Amplitude Sweeps
start_row = 3
end_row = 33

ETQ07NaSal015_01cnf_strain_in1 = pd.read_excel(ETQ07NaSal015_01cnf, sheet_name='Amplitude - 1', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_01cnf_g1_in1= pd.read_excel(ETQ07NaSal015_01cnf, sheet_name='Amplitude - 1', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_01cnf_g2_in1 = pd.read_excel(ETQ07NaSal015_01cnf, sheet_name='Amplitude - 1', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

ETQ07NaSal015_01cnf_strain_de1 = pd.read_excel(ETQ07NaSal015_01cnf, sheet_name='Amplitude - 2', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_01cnf_g1_de1= pd.read_excel(ETQ07NaSal015_01cnf, sheet_name='Amplitude - 2', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_01cnf_g2_de1 = pd.read_excel(ETQ07NaSal015_01cnf, sheet_name='Amplitude - 2', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

ETQ07NaSal015_01cnf_strain_in2 = pd.read_excel(ETQ07NaSal015_01cnf, sheet_name='Amplitude - 3', usecols=[3], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_01cnf_g1_in2= pd.read_excel(ETQ07NaSal015_01cnf, sheet_name='Amplitude - 3', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_01cnf_g2_in2 = pd.read_excel(ETQ07NaSal015_01cnf, sheet_name='Amplitude - 3', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

# %%
ETQ07NaSal015_0cnf_strain = [ETQ07NaSal015_0cnf_strain_in1, ETQ07NaSal015_0cnf_strain_de1, ETQ07NaSal015_0cnf_strain_in2]
ETQ07NaSal015_0cnf_g1 = [ETQ07NaSal015_0cnf_g1_in1, ETQ07NaSal015_0cnf_g1_de1, ETQ07NaSal015_0cnf_g1_in2]
ETQ07NaSal015_0cnf_g2 = [ETQ07NaSal015_0cnf_g2_in1, ETQ07NaSal015_0cnf_g2_de1, ETQ07NaSal015_0cnf_g2_in2]
ETQ07NaSal015_0cnf_label_g1 = ['.', '.', '.']
ETQ07NaSal015_0cnf_label_g2 = ['1st Increasing γ', '1st Decreasing γ', '2nd Increasing γ']
markers = ['^','v', 'o']
alphas = [0.2, 0.4, 0.8]
c='k'
# Plot the data
fig, ax = plt.subplots(figsize=(6, 6))

for idx, (x, y1, y2, m, a, label1, label2) in enumerate(zip(ETQ07NaSal015_0cnf_strain, ETQ07NaSal015_0cnf_g1, ETQ07NaSal015_0cnf_g2, markers, alphas, ETQ07NaSal015_0cnf_label_g1, ETQ07NaSal015_0cnf_label_g2)):
    scatter1 = plt.scatter(x, y1, s =200, alpha = a,
                marker= m, facecolors=c, edgecolors=c, linewidths=2, label=label1)
    scatter2 = plt.scatter(x, y2, s =200, alpha = a,
                marker= m, edgecolors=c, linewidths=2, label=label2)
    scatter2.set_facecolor('none') 
  

plt.style.use('seaborn-notebook')
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Oscillatory strain, γ (%)', fontsize=20)
plt.ylabel("Storage modulus, G' (Pa) \n Loss modulus, G'' (Pa)", fontsize=20)

legend_handles = [(scatter1, scatter2) for scatter1, scatter2 in zip(scatter1.get_paths(), scatter2.get_paths())]
legend_labels = ETQ07NaSal015_0cnf_label_g2

handler_map = {}
for handle, label in zip(legend_handles, legend_labels):
    handler_map[handle] = HandlerTuple(ndivide=None, pad=0.3)

handles, labels = plt.gca().get_legend_handles_labels()
handles = handles[1::2] + handles[::2]  # Combine G1 and G2 handles
labels =  labels[1::2] + labels[::2]   # Combine G1 and G2 labels

label_colors = ['white' if i < 3 else 'black' for i in range(len(labels))]
legend = plt.legend(handles[::-1], labels[::-1], frameon=False, fontsize=14, 
           handler_map=handler_map, labelcolor=label_colors, ncol =2,
          handlelength=-5, handletextpad=4, loc = 'lower right')

plt.subplots_adjust(left=0.01, right=0.9, top=0.9, bottom=0.1)  # Adjust the values as needed
 
plt.text(5.6, 2.7, "G'  G''", fontsize=14, color='black')

plt.tick_params(axis='y', length=5, width=1, color='black', direction='out')
plt.tick_params(axis='x', length=5, width=1, color='black', direction='out')
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlim(0.1, 100)
plt.ylim(1, 100)
#plt.savefig("Amplitude Sweeps of WLM(ETQ&NaSal) at 25C.png", dpi=1500, bbox_inches='tight')
plt.show()

# %%
ETQ07NaSal015_strain = [ETQ07NaSal015_0cnf_strain_in2, ETQ07NaSal015_001cnf_strain_in2, ETQ07NaSal015_005cnf_strain_in2,  ETQ07NaSal015_01cnf_strain_in2]
ETQ07NaSal015_g1 = [ETQ07NaSal015_0cnf_g1_in2, ETQ07NaSal015_001cnf_g1_in2, ETQ07NaSal015_005cnf_g1_in2, ETQ07NaSal015_01cnf_g1_in2]
ETQ07NaSal015_g2 = [ETQ07NaSal015_0cnf_g2_in2, ETQ07NaSal015_001cnf_g2_in2, ETQ07NaSal015_005cnf_g2_in2, ETQ07NaSal015_01cnf_g2_in2]
ETQ07NaSal015_label_g1 = ['.', '.','.', '.']
ETQ07NaSal015_label_g2 = [0, 0.01, 0.05, 0.1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 ETQ07NaSal015_strain = [ETQ07NaSal015_0cnf_strain_in2, ETQ07NaSal015_001cnf_strain_in2, ETQ07NaSal015_005cnf_strain_in2,  ETQ07NaSal015_01cnf_strain_in2]
#       2 ETQ07NaSal015_g1 = [ETQ07NaSal015_0cnf_g1_in2, ETQ07NaSal015_001cnf_g1_in2, ETQ07NaSal015_005cnf_g1_in2, ETQ07NaSal015_01cnf_g1_in2]
#       3 ETQ07NaSal015_g2 = [ETQ07NaSal015_0cnf_g2_in2, ETQ07NaSal015_001cnf_g2_in2, ETQ07NaSal015_005cnf_g2_in2, ETQ07NaSal015_01cnf_g2_in2]
#
# NameError: name 'ETQ07NaSal015_0cnf_strain_in2' is not defined

# %%
#frequency Sweeps
start_row = 3
end_row = 33

ETQ07NaSal015_0cnf_fre_25C = pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Frequency - 4', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_0cnf_g1_fre_25C= pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Frequency - 4', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_0cnf_g2_fre_25C = pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Frequency - 4', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

ETQ07NaSal015_0cnf_fre_20C = pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Frequency - 5', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_0cnf_g1_fre_20C= pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Frequency - 5', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_0cnf_g2_fre_20C = pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Frequency - 5', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

ETQ07NaSal015_0cnf_fre_15C = pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Frequency - 6', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_0cnf_g1_fre_15C= pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Frequency - 6', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_0cnf_g2_fre_15C = pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Frequency - 6', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

ETQ07NaSal015_0cnf_fre_10C = pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Frequency - 7', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_0cnf_g1_fre_10C= pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Frequency - 7', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_0cnf_g2_fre_10C = pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Frequency - 7', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

ETQ07NaSal015_0cnf_fre_5C = pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Frequency - 8', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_0cnf_g1_fre_5C= pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Frequency - 8', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_0cnf_g2_fre_5C = pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Frequency - 8', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

ETQ07NaSal015_0cnf_fre_0C = pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Frequency - 9', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_0cnf_g1_fre_0C= pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Frequency - 9', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_0cnf_g2_fre_0C = pd.read_excel(ETQ07NaSal015_0cnf, sheet_name='Frequency - 9', usecols=[8], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

# %%
#frequency Sweeps
start_row = 3
end_row = 33

ETQ07NaSal015_001cnf_fre_25C = pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Frequency - 4', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_001cnf_g1_fre_25C= pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Frequency - 4', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_001cnf_g2_fre_25C = pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Frequency - 4', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

ETQ07NaSal015_001cnf_fre_20C = pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Frequency - 5', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_001cnf_g1_fre_20C= pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Frequency - 5', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_001cnf_g2_fre_20C = pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Frequency - 5', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

ETQ07NaSal015_001cnf_fre_15C = pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Frequency - 6', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_001cnf_g1_fre_15C= pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Frequency - 6', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_001cnf_g2_fre_15C = pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Frequency - 6', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

ETQ07NaSal015_001cnf_fre_10C = pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Frequency - 7', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_001cnf_g1_fre_10C= pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Frequency - 7', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_001cnf_g2_fre_10C = pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Frequency - 7', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

ETQ07NaSal015_001cnf_fre_5C = pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Frequency - 8', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_001cnf_g1_fre_5C= pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Frequency - 8', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_001cnf_g2_fre_5C = pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Frequency - 8', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

ETQ07NaSal015_001cnf_fre_0C = pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Frequency - 9', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_001cnf_g1_fre_0C= pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Frequency - 9', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_001cnf_g2_fre_0C = pd.read_excel(ETQ07NaSal015_001cnf, sheet_name='Frequency - 9', usecols=[8], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

# %%
#frequency Sweeps
start_row = 3
end_row = 33

ETQ07NaSal015_005cnf_fre_25C = pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Frequency - 4', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_005cnf_g1_fre_25C= pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Frequency - 4', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_005cnf_g2_fre_25C = pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Frequency - 4', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

ETQ07NaSal015_005cnf_fre_20C = pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Frequency - 5', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_005cnf_g1_fre_20C= pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Frequency - 5', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_005cnf_g2_fre_20C = pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Frequency - 5', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

ETQ07NaSal015_005cnf_fre_15C = pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Frequency - 6', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_005cnf_g1_fre_15C= pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Frequency - 6', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_005cnf_g2_fre_15C = pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Frequency - 6', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

ETQ07NaSal015_005cnf_fre_10C = pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Frequency - 7', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_005cnf_g1_fre_10C= pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Frequency - 7', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_005cnf_g2_fre_10C = pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Frequency - 7', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

ETQ07NaSal015_005cnf_fre_5C = pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Frequency - 8', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_005cnf_g1_fre_5C= pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Frequency - 8', usecols=[6], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_005cnf_g2_fre_5C = pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Frequency - 8', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

ETQ07NaSal015_005cnf_fre_0C = pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Frequency - 9', usecols=[0], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_005cnf_g1_fre_0C= pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Frequency - 9', usecols=[7], nrows=end_row - start_row + 1, skiprows=range(1, start_row))
ETQ07NaSal015_005cnf_g2_fre_0C = pd.read_excel(ETQ07NaSal015_005cnf, sheet_name='Frequency - 9', usecols=[8], nrows=end_row - start_row + 1, skiprows=range(1, start_row))

# %%
ETQ07NaSal015_0cnf_fre = [ETQ07NaSal015_0cnf_fre_25C, ETQ07NaSal015_0cnf_fre_20C, ETQ07NaSal015_0cnf_fre_15C,
                            ETQ07NaSal015_0cnf_fre_10C, ETQ07NaSal015_0cnf_fre_5C, ETQ07NaSal015_0cnf_fre_0C] 
ETQ07NaSal015_0cnf_g1_fre = [ETQ07NaSal015_0cnf_g1_fre_25C, ETQ07NaSal015_0cnf_g1_fre_20C, ETQ07NaSal015_0cnf_g1_fre_15C, 
                               ETQ07NaSal015_0cnf_g1_fre_10C, ETQ07NaSal015_0cnf_g1_fre_5C, ETQ07NaSal015_0cnf_g1_fre_0C]
ETQ07NaSal015_0cnf_g2_fre = [ETQ07NaSal015_0cnf_g2_fre_25C, ETQ07NaSal015_0cnf_g2_fre_20C, ETQ07NaSal015_0cnf_g2_fre_15C, 
                               ETQ07NaSal015_0cnf_g2_fre_10C, ETQ07NaSal015_0cnf_g2_fre_5C, ETQ07NaSal015_0cnf_g2_fre_0C]
ETQ07NaSal015_0cnf_T_label_g1 = ['.', '.', '.','.', '.','.']
ETQ07NaSal015_0cnf_T_label_g2 = [25, 20, 15, 10, 5, 0]

cmap = plt.get_cmap('coolwarm_r')

# Plot the data
fig, ax = plt.subplots(figsize=(6, 6))

for idx, (x, y1, y2, label1, label2) in enumerate(zip(ETQ07NaSal015_0cnf_fre, ETQ07NaSal015_0cnf_g1_fre, ETQ07NaSal015_0cnf_g2_fre, 
                                                      ETQ07NaSal015_0cnf_T_label_g1, ETQ07NaSal015_0cnf_T_label_g2)):
    if idx < 7:
        c = cmap(float(idx) / len(ETQ07NaSal015_0cnf_fre))
        scatter1 = plt.scatter(x, y1, c=np.atleast_2d(c), s =200, alpha = 0.7,
                    marker='o', facecolors=c, edgecolors=c, linewidths=2, label=label1)
        scatter2 = plt.scatter(x, y2, c=np.atleast_2d(c), s =200, alpha = 0.7,
                    marker='o', edgecolors=c, linewidths=2, label=label2)
        scatter2.set_facecolor('none')
        plot1 = plt.plot(x, y1, '-', c=c,  linewidth=1.5, alpha=0.6)
        plot2 = plt.plot(x, y2, '-', c=c,  linewidth=1.5, alpha=0.6)
  

plt.style.use('seaborn-notebook')
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Angular frequency, \u03C9 (rad/s)', fontsize=20)
plt.ylabel("Storage modulus, G' (Pa) \n Loss modulus, G'' (Pa)", fontsize=20)

legend_handles = [(scatter1, scatter2) for scatter1, scatter2 in zip(scatter1.get_paths(), scatter2.get_paths())]
legend_labels = ETQ07NaSal015_0cnf_T_label_g2

handler_map = {}
for handle, label in zip(legend_handles, legend_labels):
    handler_map[handle] = HandlerTuple(ndivide=None, pad=0.3)

handles, labels = plt.gca().get_legend_handles_labels()
handles = handles[1::2] + handles[::2]  # Combine G1 and G2 handles
labels =  labels[1::2] + labels[::2]   # Combine G1 and G2 labels

label_colors = ['white' if i < 6 else 'black' for i in range(len(labels))]
legend = plt.legend(handles[::-1], labels[::-1], frameon=False, fontsize=14, 
           handler_map=handler_map, labelcolor=label_colors, ncol =2,
          handlelength=-5, handletextpad=4, loc = 'best')

plt.subplots_adjust(left=0.01, right=0.9, top=0.9, bottom=0.1)  # Adjust the values as needed
 
plt.text(16, 1.5, "G' G''T($^\circ$C)", fontsize=14, color='black')

plt.tick_params(axis='y', length=5, width=1, color='black', direction='out')
plt.tick_params(axis='x', length=5, width=1, color='black', direction='out')
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlim(0.1, 50)
plt.ylim(0.1, 100)
#plt.savefig("Frequency Sweeps WLM(ETQ&NaSal) 0CNF Varying T.png", dpi=1500, bbox_inches='tight')
plt.show()

# %%
def model1(ω, G0, λ_i):
    return G0 * (ω**2 * λ_i**2) / (1 + ω**2 * λ_i**2)

def model2(ω, G0, λ_i):
    return G0 * (ω * λ_i) / (1 + ω**2 * λ_i**2)

fitting_results_CNFWLM_0 = []

cmap = plt.get_cmap('coolwarm_r')

# Plot the data
fig, ax = plt.subplots(figsize=(6, 6))

for idx, (x, y1, y2, label1, label2) in enumerate(zip(ETQ07NaSal015_0cnf_fre, ETQ07NaSal015_0cnf_g1_fre, ETQ07NaSal015_0cnf_g2_fre, 
                                                      ETQ07NaSal015_0cnf_T_label_g1, ETQ07NaSal015_0cnf_T_label_g2)):
     if idx < 6:
        c = cmap(float(idx) / len(ETQ07NaSal015_0cnf_fre))
        scatter1 = plt.scatter(x, y1, c=np.atleast_2d(c), s =200, alpha = 0.4,
                    marker='o', facecolors=c, edgecolors=c, linewidths=2, label=label1)
        scatter2 = plt.scatter(x, y2, c=np.atleast_2d(c), s =200, alpha = 0.4,
                    marker='o', edgecolors=c, linewidths=2, label=label2)
        scatter2.set_facecolor('none')

        x_flat_CNFWLM = np.ravel(x)
        y1_flat_CNFWLM = np.ravel(y1)
        y2_flat_CNFWLM = np.ravel(y2)

        # Improved initial guesses for G0 and λ
        G0_guess = np.mean([np.max(y1_flat_CNFWLM), np.max(y2_flat_CNFWLM)])
        lambda_guess = 0.01

        # Perform curve fitting using the same G0 and λ value for both models
        popt1_CNFWLM, _ = curve_fit(model1, x_flat_CNFWLM, y1_flat_CNFWLM, p0=[G0_guess, lambda_guess])
        popt2_CNFWLM, _ = curve_fit(model2, x_flat_CNFWLM, y2_flat_CNFWLM, p0=[G0_guess, lambda_guess])

        G0_CNFWLM = (popt1_CNFWLM[0] + popt2_CNFWLM[0]) / 2
        lambda_CNFWLM = (popt1_CNFWLM[1] + popt2_CNFWLM[1]) / 2

        # Extend the range of x values for plotting the fitted curves
        extended_x_range = np.logspace(-1.5, 1.7, 1000)
        extended_y1 = model1(extended_x_range, G0_CNFWLM, lambda_CNFWLM)
        extended_y2 = model2(extended_x_range, G0_CNFWLM, lambda_CNFWLM)

        plt.plot(extended_x_range, extended_y1, '-', c=c, linewidth=3)
        plt.plot(extended_x_range, extended_y2, '--', c=c, linewidth=3)

        fitting_results_CNFWLM_0.append({
            'Data Set': idx + 1,
            'T': label2,
            "G0": f"{G0_CNFWLM:.2f}",
            "λ": f"{lambda_CNFWLM:.4f}",  # Use a common lambda value for both G' and G''
        })

fitting_df_CNFWLM_0 = pd.DataFrame(fitting_results_CNFWLM_0)
print(fitting_df_CNFWLM_0)

plt.style.use('seaborn-notebook')
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Angular frequency, \u03C9 (rad/s)', fontsize=20)
plt.ylabel("Storage modulus, G' (Pa) \n Loss modulus, G'' (Pa)", fontsize=20)

legend_handles = [(scatter1, scatter2) for scatter1, scatter2 in zip(scatter1.get_paths(), scatter2.get_paths())]
legend_labels = ETQ07NaSal015_0cnf_T_label_g2

handler_map = {}
for handle, label in zip(legend_handles, legend_labels):
    handler_map[handle] = HandlerTuple(ndivide=None, pad=0.3)

handles, labels = plt.gca().get_legend_handles_labels()
handles = handles[1::2] + handles[::2]  # Combine G1 and G2 handles
labels = labels[1::2] + labels[::2]   # Combine G1 and G2 labels

label_colors = ['white' if i < 6 else 'black' for i in range(len(labels))]
legend = plt.legend(handles[::-1], labels[::-1], frameon=False, fontsize=14,
                    handler_map=handler_map, labelcolor=label_colors, ncol=2,
                     handlelength=-5, handletextpad=4, loc = 'lower center')

plt.subplots_adjust(left=0.01, right=0.9, top=0.9, bottom=0.1)  # Adjust the values as needed
 
plt.text(0.63, 1.4, "G'  G''  T($^\circ$C)", fontsize=14, color='black')

plt.tick_params(axis='y', length=5, width=1, color='black', direction='out')
plt.tick_params(axis='x', length=5, width=1, color='black', direction='out')
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlim(0.05, 50)
plt.ylim(0.1, 100)
#plt.savefig("Frequency Sweeps WLM(ETQ&NaSal) 0CNF Varying T fitted.png", dpi=1500, bbox_inches='tight')
plt.show()
# Out:
#    Data Set   T     G0       λ
# 0         1  25  69.11  0.3921
# 1         2  20  68.19  0.6774
# 2         3  15  67.23  1.1582
# 3         4  10  66.00  1.9950
# 4         5   5  64.51  3.5901
# 5         6   0  62.76  6.6358

# %%
ETQ07NaSal015_0cnf_lambda = fitting_df_CNFWLM_0.loc[:, 'λ']  # in [s/rad]
ETQ07NaSal015_0cnf_lambda_numeric = pd.to_numeric(ETQ07NaSal015_0cnf_lambda, errors='coerce')
ETQ07NaSal015_0cnf_lambda_values_s = ETQ07NaSal015_0cnf_lambda_numeric / 0.1591549
ETQ07NaSal015_0cnf_lambda_values_ln = [np.log(lambda_i) for lambda_i in ETQ07NaSal015_0cnf_lambda_values_s]

Temps = ETQ07NaSal015_0cnf_T_label_g2
Reciprocal_Temps = [1 / (temp + 273) for temp in Temps]
x = np.array(Reciprocal_Temps)
y = np.array(ETQ07NaSal015_0cnf_lambda_values_ln)

def linear_model(T, m, c):
    return m * T + c

cmap = plt.get_cmap('coolwarm_r')

fig, ax = plt.subplots(figsize=(6, 6))

for idx, (x_val, y_val) in enumerate(zip(x, y)):
    c = cmap(float(idx) / len(ETQ07NaSal015_0cnf_lambda_values_s))
    scatter1 = plt.scatter(x_val, y_val, c=np.atleast_2d(c), s=300, alpha=1, marker='o', facecolors=c, edgecolors='k', linewidths=2)

slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
plt.plot(x, slope * x + intercept, color='k')
print(f"Ea: {slope:.2f}")
plt.style.use('seaborn-notebook')
plt.rcParams['font.family'] = 'Times'
plt.xlabel('1/T (K$^{-1}$)', fontsize=20)
plt.ylabel("ln λ (s)", fontsize=20)  
plt.tick_params(axis='y', length=5, width=1, color='black', direction='out')
plt.tick_params(axis='x', length=5, width=1, color='black', direction='out')
plt.xticks([0.0033, 0.0034, 0.0035, 0.0036, 0.0037], fontsize=18)
plt.yticks([0, 1, 2, 3,4], fontsize=18)
#plt.savefig("Relaxation 0CNF Varying T.png", dpi=1500, bbox_inches='tight')
plt.show()
print(ETQ07NaSal015_0cnf_lambda_values_s)
#print(ETQ07NaSal015_0cnf_lambda_values_ln)
# Out:
# Ea: 9156.98
# 0     2.463638
# 1     4.256231
# 2     7.277187
# 3    12.534958
# 4    22.557270
# 5    41.693972
# Name: λ, dtype: float64

# %%
ETQ07NaSal015_001cnf_fre = [ETQ07NaSal015_001cnf_fre_25C, ETQ07NaSal015_001cnf_fre_20C, ETQ07NaSal015_001cnf_fre_15C,
                            ETQ07NaSal015_001cnf_fre_10C, ETQ07NaSal015_001cnf_fre_5C, ETQ07NaSal015_001cnf_fre_0C] 
ETQ07NaSal015_001cnf_g1_fre = [ETQ07NaSal015_001cnf_g1_fre_25C, ETQ07NaSal015_001cnf_g1_fre_20C, ETQ07NaSal015_001cnf_g1_fre_15C, 
                               ETQ07NaSal015_001cnf_g1_fre_10C, ETQ07NaSal015_001cnf_g1_fre_5C, ETQ07NaSal015_001cnf_g1_fre_0C]
ETQ07NaSal015_001cnf_g2_fre = [ETQ07NaSal015_001cnf_g2_fre_25C, ETQ07NaSal015_001cnf_g2_fre_20C, ETQ07NaSal015_001cnf_g2_fre_15C, 
                               ETQ07NaSal015_001cnf_g2_fre_10C, ETQ07NaSal015_001cnf_g2_fre_5C, ETQ07NaSal015_001cnf_g2_fre_0C]
ETQ07NaSal015_001cnf_T_label_g1 = ['.', '.', '.','.', '.','.']
ETQ07NaSal015_001cnf_T_label_g2 = [25, 20, 15, 10, 5, 0]

cmap = plt.get_cmap('bwr_r')

# Plot the data
fig, ax = plt.subplots(figsize=(6, 6))

for idx, (x, y1, y2, label1, label2) in enumerate(zip(ETQ07NaSal015_001cnf_fre, ETQ07NaSal015_001cnf_g1_fre, ETQ07NaSal015_001cnf_g2_fre, 
                                                      ETQ07NaSal015_001cnf_T_label_g1, ETQ07NaSal015_001cnf_T_label_g2)):
    if idx < 7:
        c = cmap(float(idx) / len(ETQ07NaSal015_001cnf_fre))
        scatter1 = plt.scatter(x, y1, c=np.atleast_2d(c), s =200, alpha = 0.7,
                    marker='o', facecolors=c, edgecolors=c, linewidths=2, label=label1)
        scatter2 = plt.scatter(x, y2, c=np.atleast_2d(c), s =200, alpha = 0.7,
                    marker='o', edgecolors=c, linewidths=2, label=label2)
        scatter2.set_facecolor('none')
        plot1 = plt.plot(x, y1, '-', c=c,  linewidth=1.5, alpha=0.6)
        plot2 = plt.plot(x, y2, '-', c=c,  linewidth=1.5, alpha=0.6)
  

plt.style.use('seaborn-notebook')
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Angular frequency, \u03C9 (rad/s)', fontsize=20)
plt.ylabel("Storage modulus, G' (Pa) \n Loss modulus, G'' (Pa)", fontsize=20)

legend_handles = [(scatter1, scatter2) for scatter1, scatter2 in zip(scatter1.get_paths(), scatter2.get_paths())]
legend_labels = ETQ07NaSal015_001cnf_T_label_g2

handler_map = {}
for handle, label in zip(legend_handles, legend_labels):
    handler_map[handle] = HandlerTuple(ndivide=None, pad=0.3)

handles, labels = plt.gca().get_legend_handles_labels()
handles = handles[1::2] + handles[::2]  # Combine G1 and G2 handles
labels =  labels[1::2] + labels[::2]   # Combine G1 and G2 labels

label_colors = ['white' if i < 6 else 'black' for i in range(len(labels))]
legend = plt.legend(handles[::-1], labels[::-1], frameon=False, fontsize=14, 
           handler_map=handler_map, labelcolor=label_colors, ncol =2,
          handlelength=-5, handletextpad=4, loc = 'best')

plt.subplots_adjust(left=0.01, right=0.9, top=0.9, bottom=0.1)  # Adjust the values as needed
 
plt.text(15, 1.5, "G' G'' T($^\circ$C)", fontsize=14, color='black')

plt.tick_params(axis='y', length=5, width=1, color='black', direction='out')
plt.tick_params(axis='x', length=5, width=1, color='black', direction='out')
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlim(0.1, 50)
plt.ylim(0.1, 100)
#plt.savefig("Frequency Sweeps WLM(ETQ&NaSal) 0.01CNF Varying T.png", dpi=1500, bbox_inches='tight')
plt.show()

# %%
def model1(ω, G0, λ_i):
    return G0 * (ω**2 * λ_i**2) / (1 + ω**2 * λ_i**2)

def model2(ω, G0, λ_i):
    return G0 * (ω * λ_i) / (1 + ω**2 * λ_i**2)

fitting_results_CNFWLM = []

cmap = plt.get_cmap('bwr_r')

# Plot the data
fig, ax = plt.subplots(figsize=(6, 6))

for idx, (x, y1, y2, label1, label2) in enumerate(zip(ETQ07NaSal015_001cnf_fre, ETQ07NaSal015_001cnf_g1_fre, ETQ07NaSal015_001cnf_g2_fre, 
                                                      ETQ07NaSal015_001cnf_T_label_g1, ETQ07NaSal015_001cnf_T_label_g2)):
     if idx < 6:
        c = cmap(float(idx) / len(ETQ07NaSal015_001cnf_fre))
        scatter1 = plt.scatter(x, y1, c=np.atleast_2d(c), s =200, alpha = 0.4,
                    marker='o', facecolors=c, edgecolors=c, linewidths=2, label=label1)
        scatter2 = plt.scatter(x, y2, c=np.atleast_2d(c), s =200, alpha = 0.4,
                    marker='o', edgecolors=c, linewidths=2, label=label2)
        scatter2.set_facecolor('none')

        x_flat_CNFWLM = np.ravel(x)
        y1_flat_CNFWLM = np.ravel(y1)
        y2_flat_CNFWLM = np.ravel(y2)

        # Improved initial guesses for G0 and λ
        G0_guess = np.mean([np.max(y1_flat_CNFWLM), np.max(y2_flat_CNFWLM)])
        lambda_guess = 0.01

        # Perform curve fitting using the same G0 and λ value for both models
        popt1_CNFWLM, _ = curve_fit(model1, x_flat_CNFWLM, y1_flat_CNFWLM, p0=[G0_guess, lambda_guess])
        popt2_CNFWLM, _ = curve_fit(model2, x_flat_CNFWLM, y2_flat_CNFWLM, p0=[G0_guess, lambda_guess])

        G0_CNFWLM = (popt1_CNFWLM[0] + popt2_CNFWLM[0]) / 2
        lambda_CNFWLM = (popt1_CNFWLM[1] + popt2_CNFWLM[1]) / 2

        # Extend the range of x values for plotting the fitted curves
        extended_x_range = np.logspace(-1.5, 1.7, 1000)
        extended_y1 = model1(extended_x_range, G0_CNFWLM, lambda_CNFWLM)
        extended_y2 = model2(extended_x_range, G0_CNFWLM, lambda_CNFWLM)

        plt.plot(extended_x_range, extended_y1, '-', c=c, linewidth=3)
        plt.plot(extended_x_range, extended_y2, '--', c=c, linewidth=3)

        fitting_results_CNFWLM.append({
            'Data Set': idx + 1,
            'T': label2,
            "G0": f"{G0_CNFWLM:.2f}",
            "λ": f"{lambda_CNFWLM:.4f}",  # Use a common lambda value for both G' and G''
        })

fitting_df_CNFWLM = pd.DataFrame(fitting_results_CNFWLM)
print(fitting_df_CNFWLM)

plt.style.use('seaborn-notebook')
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Angular frequency, \u03C9 (rad/s)', fontsize=20)
plt.ylabel("Storage modulus, G' (Pa) \n Loss modulus, G'' (Pa)", fontsize=20)

legend_handles = [(scatter1, scatter2) for scatter1, scatter2 in zip(scatter1.get_paths(), scatter2.get_paths())]
legend_labels = ETQ07NaSal015_001cnf_T_label_g2

handler_map = {}
for handle, label in zip(legend_handles, legend_labels):
    handler_map[handle] = HandlerTuple(ndivide=None, pad=0.3)

handles, labels = plt.gca().get_legend_handles_labels()
handles = handles[1::2] + handles[::2]  # Combine G1 and G2 handles
labels = labels[1::2] + labels[::2]   # Combine G1 and G2 labels

label_colors = ['white' if i < 6 else 'black' for i in range(len(labels))]
legend = plt.legend(handles[::-1], labels[::-1], frameon=False, fontsize=14,
                    handler_map=handler_map, labelcolor=label_colors, ncol=2,
                     handlelength=-5, handletextpad=4, loc = 'lower center')

plt.subplots_adjust(left=0.01, right=0.9, top=0.9, bottom=0.1)  # Adjust the values as needed
 
plt.text(0.62, 1.4, "G'  G''  T($^\circ$C)", fontsize=14, color='black')

plt.tick_params(axis='y', length=5, width=1, color='black', direction='out')
plt.tick_params(axis='x', length=5, width=1, color='black', direction='out')
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlim(0.05, 50)
plt.ylim(0.1, 100)
#plt.savefig("Frequency Sweeps WLM(ETQ&NaSal) 0.01CNF Varying T fitted.png", dpi=1500, bbox_inches='tight')
plt.show()
# Out:
#    Data Set   T     G0       λ
# 0         1  25  75.35  0.3370
# 1         2  20  74.15  0.5362
# 2         3  15  73.32  0.8533
# 3         4  10  72.66  1.3852
# 4         5   5  71.57  2.3560
# 5         6   0  69.44  4.1339

# %%
ETQ07NaSal015_001cnf_lambda = fitting_df_CNFWLM.loc[:, 'λ']  # in [s/rad]
ETQ07NaSal015_001cnf_lambda_numeric = pd.to_numeric(ETQ07NaSal015_001cnf_lambda, errors='coerce')
ETQ07NaSal015_001cnf_lambda_values_s = ETQ07NaSal015_001cnf_lambda_numeric / 0.1591549
ETQ07NaSal015_001cnf_lambda_values_ln = [np.log(lambda_i) for lambda_i in ETQ07NaSal015_001cnf_lambda_values_s]

Temps = ETQ07NaSal015_001cnf_T_label_g2
Reciprocal_Temps = [1 / (temp + 273) for temp in Temps]
x = np.array(Reciprocal_Temps)
y = np.array(ETQ07NaSal015_001cnf_lambda_values_ln)

def linear_model(T, m, c):
    return m * T + c

cmap = plt.get_cmap('bwr_r')

fig, ax = plt.subplots(figsize=(6, 6))

for idx, (x_val, y_val) in enumerate(zip(x, y)):
    c = cmap(float(idx) / len(ETQ07NaSal015_001cnf_lambda_values_s))
    scatter1 = plt.scatter(x_val, y_val, c=np.atleast_2d(c), s=300, alpha=0.6, marker='o', facecolors=c, edgecolors='k', linewidths=2)

slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
plt.plot(x, slope * x + intercept, color='k')
print(f"Ea: {slope:.2f}")
plt.style.use('seaborn-notebook')
plt.rcParams['font.family'] = 'Times'
plt.xlabel('1/T (K$^{-1}$)', fontsize=20)
plt.ylabel("ln λ (s)", fontsize=20)  
plt.tick_params(axis='y', length=5, width=1, color='black', direction='out')
plt.tick_params(axis='x', length=5, width=1, color='black', direction='out')
plt.xticks([0.0033, 0.0034, 0.0035, 0.0036, 0.0037], fontsize=18)
plt.yticks([0, 1, 2, 3, 4], fontsize=18)
#plt.savefig("Relaxation 0.01CNF Varying T.png", dpi=1500, bbox_inches='tight')
plt.show()
print(ETQ07NaSal015_001cnf_lambda_values_s)
# Out:
# Ea: 8122.53
# 0     2.117434
# 1     3.369045
# 2     5.361443
# 3     8.703471
# 4    14.803189
# 5    25.974067
# Name: λ, dtype: float64
